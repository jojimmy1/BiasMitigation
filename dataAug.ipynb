# %%
import numpy
import pandas
from sklearn.preprocessing import LabelEncoder

# %%
kiva_label = pandas.read_csv('/home/li3975/cs587/data/kiva/kiva_loans.csv')

kiva_label = kiva_label.drop(columns=['id',  'activity', 'country', 'posted_time', 
                          'disbursed_time', 'funded_time', 'tags', 'use', 
                          'region', 'date'])
kiva_label = kiva_label.dropna()

# %%
kiva_label = kiva_label[~kiva_label['borrower_genders'].str.contains(',', na=False)]

print(kiva_label.shape)

le = LabelEncoder()
kiva_label['borrower_genders'] = le.fit_transform(kiva_label['borrower_genders'])
# mapping = dict(zip(le.classes_, range(1, len(le.classes_)+1)))
# print(len(mapping))
# print(mapping['male'])
kiva_label['country_code'] = le.fit_transform(kiva_label['country_code'])
kiva_label['currency'] = le.fit_transform(kiva_label['currency'])
kiva_label['repayment_interval'] = le.fit_transform(kiva_label['repayment_interval'])
kiva_label['sector'] = le.fit_transform(kiva_label['sector'])
# Out:
# (548116, 10)

# %%
print(kiva_label.shape)
kiva_label
# Out:
# (548116, 10)
#         funded_amount  loan_amount  sector  country_code  currency  \
# 0               300.0        300.0       6            51        39
# 2               150.0        150.0      13            27        19
# 3               200.0        200.0       1            51        39
# 4               400.0        400.0       6            51        39
# 6               200.0        200.0       0            27        19
# ...               ...          ...     ...           ...       ...
# 671199            0.0         25.0       0            53        52
# 671200            0.0         25.0       0            53        52
# 671201           25.0         25.0       0            30        21
# 671203            0.0         25.0       0            30        21
# 671204            0.0         25.0       0            30        21
#
#         partner_id  term_in_months  lender_count  borrower_genders  \
# 0            247.0            12.0            12                 0
# ...

# %%
kiva_label.to_csv('/home/li3975/cs587/dataAug/kiva_label.csv', index=False)

# %%
kiva_onehot = pandas.read_csv('/home/li3975/cs587/data/kiva/kiva_loans.csv')

kiva_onehot = kiva_onehot.drop(columns=['id',  'activity', 'country', 'posted_time', 
                          'disbursed_time', 'funded_time', 'tags', 'use', 
                          'region', 'date'])
kiva_onehot = kiva_onehot.dropna()
kiva_onehot.shape
# Out:
# (653888, 10)

# %%
kiva_onehot = kiva_onehot[~kiva_onehot['borrower_genders'].str.contains(',', na=False)]
# kiva_onehot = kiva_onehot[~kiva_onehot['borrower_genders'].str.contains("\"", na=False)]
kiva_onehot.shape
# Out:
# (548116, 10)

# %%
kiva_onehot = pandas.get_dummies(kiva_onehot, columns=['country_code', 'currency', 'repayment_interval', 'sector', 'borrower_genders'])

# %%
print(kiva_onehot.shape)
kiva_onehot
# Out:
# (548116, 165)
#         funded_amount  loan_amount  partner_id  term_in_months  lender_count  \
# 0               300.0        300.0       247.0            12.0            12
# 2               150.0        150.0       334.0            43.0             6
# 3               200.0        200.0       247.0            11.0             8
# 4               400.0        400.0       245.0            14.0            16
# 6               200.0        200.0       334.0            43.0             8
# ...               ...          ...         ...             ...           ...
# 671199            0.0         25.0        58.0            13.0             0
# 671200            0.0         25.0        58.0            13.0             0
# 671201           25.0         25.0       138.0            13.0             1
# 671203            0.0         25.0       138.0            13.0             0
# 671204            0.0         25.0       138.0            13.0             0
#
# ...

# %%
kiva_onehot.to_csv('/home/li3975/cs587/dataAug/kiva_onehot.csv', index=False)

# %%
studentperf_label = pandas.read_csv("/home/li3975/cs587/data/student-performance-factors/StudentPerformanceFactors.csv")
studentperf_onehot = pandas.read_csv("/home/li3975/cs587/data/student-performance-factors/StudentPerformanceFactors.csv")

# %%
studentperf_label.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
studentperf_label.drop(columns={'Parental_Involvement', 'Access_to_Resources', 'Extracurricular_Activities', 'Internet_Access', 'School_Type', 'Peer_Influence'}, inplace = True)
studentperf_onehot.drop(columns={'Parental_Involvement', 'Access_to_Resources', 'Extracurricular_Activities', 'Internet_Access', 'School_Type', 'Peer_Influence'}, inplace = True)

# %%
studentperf_label.dtypes
# Out:
# Hours_Studied                int64
# Attendance                   int64
# Sleep_Hours                  int64
# Previous_Scores              int64
# Motivation_Level            object
# Tutoring_Sessions            int64
# Family_Income               object
# Teacher_Quality             object
# Physical_Activity            int64
# Learning_Disabilities       object
# Parental_Education_Level    object
# Distance_from_Home          object
# Gender                      object
# Exam_Score                   int64
# dtype: object

# %%
import pandas as pd
#create naive encoding:
studentperf_label = studentperf_label.dropna()
studentperf_onehot = studentperf_onehot.dropna()
le = LabelEncoder()

cat_columns = []
for column in studentperf_label.select_dtypes(include=['object']).columns:
    studentperf_label[column] = le.fit_transform(studentperf_label[column])
    cat_columns.append(column)

#create one hot
studentperf_onehot = pd.get_dummies(studentperf_onehot, columns=cat_columns)

# %%
studentperf_label
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0                23          84            7               73
# 1                19          64            8               59
# 2                24          98            7               91
# 3                29          89            8               98
# 4                19          92            6               65
# ...             ...         ...          ...              ...
# 6602             25          69            7               76
# 6603             23          76            8               81
# 6604             20          90            6               65
# 6605             10          86            6               91
# 6606             15          67            9               94
#
#       Motivation_Level  Tutoring_Sessions  Family_Income  Teacher_Quality  \
# 0                    1                  0              1                2
# ...

# %%
studentperf_onehot
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0                23          84            7               73
# 1                19          64            8               59
# 2                24          98            7               91
# 3                29          89            8               98
# 4                19          92            6               65
# ...             ...         ...          ...              ...
# 6602             25          69            7               76
# 6603             23          76            8               81
# 6604             20          90            6               65
# 6605             10          86            6               91
# 6606             15          67            9               94
#
#      Motivation_Level  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0                 Low                  0           Low          Medium
# 1                 Low                  2        Medium          Medium
# ...

# %%
studentperf_onehot.to_csv("/home/li3975/cs587/dataAug/studentperf_onehot.csv")
studentperf_label.to_csv("/home/li3975/cs587/dataAug/studentperf_label.csv")
